# %%
import os.path as osp
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

sys.path.append("../src")
sys.path.append("../src/model_arch_utils")
from score_utils import calc_performance, reoder_df

# %%
root = osp.join("..", "outputs", "densenet_cifar10_20201212_162449")
root = osp.join("..", "outputs", "densenet_cifar10_20201222_121831")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# densenet cifar10
# trainset_features=(50000, 343)
# testset_ind_features=(10000, 343)
# testset_ind_probs=(10000, 10)
# testset_ind_labels=(10000,)
#
# OOD:
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_Imagenet_resize_features.npy
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_LSUN_resize_features.npy
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_cifar100_features.npy
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_cifar10_features.npy
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_iSUN_features.npy
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_svhn_features.npy
# ../outputs/densenet_cifar10_20201222_121831/densenet_cifar10_trainset_features.npy
# Imagenet_resize:	features=(10000, 343)
# LSUN_resize:	features=(10000, 343)
# iSUN:	features=(8925, 343)
# svhn:	features=(26032, 343)
# Acc [ERM pNML]=[0.948 0.948]
# [0/3] Imagenet_resize
# [1/3] LSUN_resize
# [2/3] iSUN
# [3/3] svhn
# pNML
# ...

# %%
root = osp.join("..", "outputs", "densenet_cifar100_20201212_162903")
root = osp.join("..", "outputs", "densenet_cifar100_20201222_122245")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# densenet cifar100
# trainset_features=(50000, 343)
# testset_ind_features=(10000, 343)
# testset_ind_probs=(10000, 100)
# testset_ind_labels=(10000,)
#
# OOD:
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_Imagenet_resize_features.npy
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_LSUN_resize_features.npy
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_cifar100_features.npy
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_cifar10_features.npy
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_iSUN_features.npy
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_svhn_features.npy
# ../outputs/densenet_cifar100_20201222_122245/densenet_cifar100_trainset_features.npy
# Imagenet_resize:	features=(10000, 343)
# LSUN_resize:	features=(10000, 343)
# cifar10:	features=(10000, 343)
# iSUN:	features=(8925, 343)
# svhn:	features=(26032, 343)
# Acc [ERM pNML]=[0.7397 0.7397]
# [0/4] Imagenet_resize
# ...

# %%
root = osp.join("..", "outputs", "densenet_svhn_20201212_174533")
root = osp.join("..", "outputs", "densenet_svhn_20201222_122701")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# densenet svhn
# trainset_features=(73257, 343)
# testset_ind_features=(26032, 343)
# testset_ind_probs=(26032, 10)
# testset_ind_labels=(26032,)
#
# OOD:
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_Imagenet_resize_features.npy
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_LSUN_resize_features.npy
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_cifar100_features.npy
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_cifar10_features.npy
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_iSUN_features.npy
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_svhn_features.npy
# ../outputs/densenet_svhn_20201222_122701/densenet_svhn_trainset_features.npy
# Imagenet_resize:	features=(10000, 343)
# LSUN_resize:	features=(10000, 343)
# cifar100:	features=(10000, 343)
# cifar10:	features=(10000, 343)
# iSUN:	features=(8925, 343)
# Acc [ERM pNML]=[0.9628918254456054 0.9628918254456054]
# [0/4] Imagenet_resize
# [1/4] LSUN_resize
# ...

# %%
root = osp.join("..", "outputs", "resnet_cifar10_20201212_163320")
root = osp.join("..", "outputs", "resnet_cifar10_20201222_123157")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# resnet cifar10
# trainset_features=(50000, 513)
# testset_ind_features=(10000, 513)
# testset_ind_probs=(10000, 10)
# testset_ind_labels=(10000,)
#
# OOD:
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_Imagenet_resize_features.npy
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_LSUN_resize_features.npy
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_cifar100_features.npy
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_cifar10_features.npy
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_iSUN_features.npy
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_svhn_features.npy
# ../outputs/resnet_cifar10_20201222_123157/resnet_cifar10_trainset_features.npy
# Imagenet_resize:	features=(10000, 513)
# LSUN_resize:	features=(10000, 513)
# iSUN:	features=(8925, 513)
# svhn:	features=(26032, 513)
# Acc [ERM pNML]=[0.9364 0.9364]
# [0/3] Imagenet_resize
# [1/3] LSUN_resize
# [2/3] iSUN
# [3/3] svhn
# pNML
# ...

# %%
root = osp.join("..", "outputs", "resnet_cifar100_20201212_163657")
root = osp.join("..", "outputs", "resnet_cifar100_20201222_123535")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# resnet cifar100
# trainset_features=(50000, 513)
# testset_ind_features=(10000, 513)
# testset_ind_probs=(10000, 100)
# testset_ind_labels=(10000,)
#
# OOD:
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_Imagenet_resize_features.npy
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_LSUN_resize_features.npy
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_cifar100_features.npy
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_cifar10_features.npy
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_iSUN_features.npy
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_svhn_features.npy
# ../outputs/resnet_cifar100_20201222_123535/resnet_cifar100_trainset_features.npy
# Imagenet_resize:	features=(10000, 513)
# LSUN_resize:	features=(10000, 513)
# cifar10:	features=(10000, 513)
# iSUN:	features=(8925, 513)
# svhn:	features=(26032, 513)
# Acc [ERM pNML]=[0.7841 0.7841]
# [0/4] Imagenet_resize
# [1/4] LSUN_resize
# ...

# %%
root = osp.join("..", "outputs", "resnet_svhn_20201212_175028")
root = osp.join("..", "outputs", "resnet_svhn_20201222_123913")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# resnet svhn
# trainset_features=(73257, 513)
# testset_ind_features=(26032, 513)
# testset_ind_probs=(26032, 10)
# testset_ind_labels=(26032,)
#
# OOD:
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_Imagenet_resize_features.npy
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_LSUN_resize_features.npy
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_cifar100_features.npy
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_cifar10_features.npy
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_iSUN_features.npy
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_svhn_features.npy
# ../outputs/resnet_svhn_20201222_123913/resnet_svhn_trainset_features.npy
# Imagenet_resize:	features=(10000, 513)
# LSUN_resize:	features=(10000, 513)
# cifar100:	features=(10000, 513)
# cifar10:	features=(10000, 513)
# iSUN:	features=(8925, 513)
# Acc [ERM pNML]=[0.9666180086047941 0.9666180086047941]
# [0/4] Imagenet_resize
# [1/4] LSUN_resize
# [2/4] cifar100
# [3/4] cifar10
# ...

# %%
root = osp.join("..", "outputs", "resnet_svhn_20201212_175028")
# root = osp.join("..", "outputs", "resnet_svhn_20201222_123913")
pnml_df, max_prob_df = calc_performance(root)
print("pNML")
display(reoder_df(pnml_df))
print()
print("Max prob")
display(reoder_df(max_prob_df))
# Out:
# resnet svhn
# trainset_features=(73257, 513)
# testset_ind_features=(26032, 513)
# testset_ind_probs=(26032, 10)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-928533e69f19> in <module>
#       1 root = osp.join("..", "outputs", "resnet_svhn_20201212_175028")
#       2 # root = osp.join("..", "outputs", "resnet_svhn_20201222_123913")
# ----> 3 pnml_df, max_prob_df = calc_performance(root)
#       4 print("pNML")
#       5 display(reoder_df(pnml_df))
#
# ~/WorkDocs/pnml_ood_detection/src/score_utils.py in calc_performance(root)
#     195     model_name, trainset_name = osp.basename(root).split('_')[0:2]
#     196     print(model_name, trainset_name)
# --> 197     trainset_features, testset_ind_features, testset_ind_probs, testset_ind_labels = load_ind_products(root, model_name,
# ...
