# %%
output_path = '../output/figures'
print('output_path = ', output_path)
is_plot_title = False
is_save_fig = True

# %%
print('plt = single_column_plt_params(plt)')
def single_column_plt_params(plt):
#     print(plt.style.available)
#     print(plt.rcParams)
    plt.style.use(['seaborn-darkgrid', 'seaborn-paper'])
    label_size = 18
    tick_size = 14
    legend_size = 12
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    plt.rc('axes', titlesize=label_size)
    plt.rc('axes', labelsize=label_size)
    plt.rc('xtick', labelsize=tick_size)
    plt.rc('ytick', labelsize=tick_size)
    plt.rc('legend', fontsize=tick_size)
    return plt

# %%
print('plt = double_column_plt_params(plt)')
def double_column_plt_params(plt):
#     print(plt.style.available)
#     print(plt.rcParams)
    plt.style.use(['seaborn-darkgrid', 'seaborn-paper'])
    label_size = 20
    tick_size = 16
    legend_size = 14
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    plt.rc('axes', titlesize=label_size)
    plt.rc('axes', labelsize=label_size)
    plt.rc('xtick', labelsize=tick_size)
    plt.rc('ytick', labelsize=tick_size)
    plt.rc('legend', fontsize=tick_size)
    return plt
